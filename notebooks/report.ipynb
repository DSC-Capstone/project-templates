# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Purpose of this Notebook:** This is an example _project report_ created from a notebook.
#
# Such a notebook follow these guidelines:
# * all computational heavy lifting is done in `run.py`. This notebook should only read in tables and figures.
# * Almost no code is used in the notebook.
# * The notebook will usually be converted to `html` or `pdf` in `run.py`. The narrative is written in markdown, while the figure and tables are imported from files which are generated by library code.
# * Parameterize as much of the results as you can as dynamically generated content -- that way you can update the data and rerun the results easily!

# %% [markdown]
# # Introduction
#
# In this report, we investigate problem X. The data that we use comes from process Y, which is related to problem X by Z.
#
# Much work in the past has studied problem X. However, to our knowledge, no one has yet to use relationship Z to use process Y to draw conclusions about X.

# %% [markdown]
# ## Analysis of the Data

# %% [markdown]
# The observed data seems to consists of independent, normally distributed variables, most of which seem to be drawn from different distributions:

# %% [markdown]
# ![scatter_matrix.png](../data/report/scatter_matrix.png)

# %% [markdown]
# The five distributions likely have different means and standard deviations (with the possible exception of $x_0$ and $x_1$). However, each looks gaussian.

# %% [markdown]
# ![histogram.png](../data/report/histogram.png)

# %% [markdown]
# The mean and standard deviation for each variable is given in the table below:

# %%
pd.read_csv('../data/report/basic_stats.csv', index_col=0)

# %% [markdown]
# Using the normality test of D'Agostino and Pearson, we see no evidence rejecting the normality of the variables:

# %%
pd.read_csv('../data/report/normality_results.csv', index_col=0)

# %% [markdown]
# We verify that $x_0$ and $x_1$ likely come from different distributions using a KS-test:

# %%
pd.read_csv('../data/report/ks_results.csv', index_col=0)
